# %% [markdown]
# Streamlit
# streamlit is an open source app frame work for ml and data science projects . It allows you to create beautiful web apps for your ml and data science projects with simple ml.
