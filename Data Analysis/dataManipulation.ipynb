# %% [markdown]
# Data Manipulation and Analysis with pandas
# Data Manipulation and analysis are key tasks in any data science or data anlysis , making it easier to clean , transform and extract insights from data.
